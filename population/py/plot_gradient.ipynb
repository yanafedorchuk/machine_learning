# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x=np.array([-5.433e-06,-2.981e-06,-9.932e-07,-5.473e-07,-6.285e-07,-5.602e-07,1.123e-06,5.289e-07])
y=np.array([1926,1939,1959,1970,1979,1989,2002,2010])

# %%
tick_val_x = [1926,1939,1959,1970,1979,1989,2002,2010]
tick_lab_x = [1926,1939,1959,1970,1979,1989,2002,2010]
plt.xticks(tick_val_x,tick_lab_x)
tick_val_y = [-5.433e-06,-2.981e-06,-9.932e-07,-0.5473e-06,-0.6285e-06,-0.5602e-06,1.123e-06,5.289e-07]
tick_lab_y = [-5.433,-2.981,-0.9932,-0.5473,-0.6285,-0.5602,1.123,0.5289]
plt.yticks(tick_val_y,tick_lab_y)
plt.title('Изменение значения углового коэффициента',fontweight='bold') 
plt.xlabel('Год')
plt.ylabel('Угловой коэффициент($10^{-6}$)')
plt.grid(True)
plt.plot(y,x)

# %%
tick_val_x = [1926,1939,1959,1970,1979,1989,2002,2010]
tick_lab_x = [1926,1939,1959,1970,1979,1989,2002,2010]
plt.xticks(tick_val_x,tick_lab_x)
tick_val_y = [-5.433e-06,-2.981e-06,-9.932e-07,-0.2073e-06,-0.7285e-06,-0.4602e-06,1.123e-06,5.289e-07]
tick_lab_y = [-5.433,-2.981,-0.9932,-0.5473,-0.6285,-0.5602,1.123,0.5289]
plt.yticks(tick_val_y,tick_lab_y)
plt.title('Изменение значения углового коэффициента',fontweight='bold') 
plt.xlabel('Год')
plt.ylabel('Угловой коэффициент($10^{-6}$)')
plt.plot(y,x)

# %% [markdown]
# # LOW (<=25)

# %%
x_1l=np.array([-0.36377545,-0.6941659,-0.68317044,-0.90792099,-0.50246012,-0.2645060,0.34384276,0.244160758])
x_2l=np.array([-0.006326,-0.18335,-0.404229,-0.53644,-0.270611,-0.10305,0.49327,0.40372])
x_3l=np.array([0.35112421,0.3274718,-0.12528755, -0.1649541,-0.03876143,0.058403741,0.64270484,0.5632827])
yl=np.array([1926,1939,1959,1970,1979,1989,2002,2010])

# %%
tick_val_x = [1926,1939,1959,1970,1979,1989,2002,2010]
tick_lab_x = [1926,1939,1959,1970,1979,1989,2002,2010]
plt.xticks(tick_val_x,tick_lab_x)
# multiple line plot
plt.title('Изменение значения коэффициента при рыночном потенциале (для маленьких городов)',fontweight='bold') 
plt.xlabel('Год')
plt.ylabel('Значение коэффициента')
x_0=[0,0,0,0,0,0,0,0]
plt.plot( yl, x_0, color='red')
plt.plot( yl, x_1l, marker='.', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=2, label='Границы доверительного интервала')
plt.plot( yl, x_2l, marker='', color='darkgreen', linewidth=4, label='значение коэффициента')
plt.plot( yl, x_3l, marker='.', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=2)
plt.legend()

# %% [markdown]
# # HIGHEST (>0,75)

# %%
x_1hst=np.array([-0.18823713,0.09825751,0.08913567,-0.09362279,-0.10604171,-0.18343684,0.015859187,0.005156776])
x_2hst=np.array([0.06668 , 0.33682,0.262100,0.01218,-0.042844, -0.115952,0.056538,0.038323])
x_3hst=np.array([0.32160067,0.5753741,0.43506508,0.11798238,0.020353984,-0.0484680750,0.09721638,0.071488770])
yhst=np.array([1926,1939,1959,1970,1979,1989,2002,2010])

tick_val_x = [1926,1939,1959,1970,1979,1989,2002,2010]
tick_lab_x = [1926,1939,1959,1970,1979,1989,2002,2010]
plt.xticks(tick_val_x,tick_lab_x)
# multiple line plot
plt.title('Изменение значения коэффициента при рыночном потенциале (для больших городов)',fontweight='bold') 
plt.xlabel('Год')
plt.ylabel('Значение коэффициента')
x_0=[0,0,0,0,0,0,0,0]
plt.plot( yhst, x_0, color='red')
plt.plot( yhst, x_1hst, marker='.', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=2, label='Границы доверительного интервала')
plt.plot( yhst, x_2hst, marker='', color='darkgreen', linewidth=4, label='значение коэффициента')
plt.plot( yhst, x_3hst, marker='.', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=2)
plt.legend()

# %% [markdown]
# # MIDDLE (0,25-0,75)

# %%
x_1m=np.array([-0.16079636,-0.03732713,-0.0007570203,-0.36619605,-0.16048493,-0.15519171,0.170136804,0.101172175])
x_2m=np.array([0.0666859,0.14720,0.12703,-0.19415,-0.083893,-0.093103,0.21719,0.137990])
x_3m=np.array([0.2941681,0.33172836,0.25481428,-0.02210676,-0.007301088,-0.031014541,0.264239739,0.17480734])
ym=np.array([1926,1939,1959,1970,1979,1989,2002,2010])

tick_val_x = [1926,1939,1959,1970,1979,1989,2002,2010]
tick_lab_x = [1926,1939,1959,1970,1979,1989,2002,2010]
plt.xticks(tick_val_x,tick_lab_x)
# multiple line plot
plt.title('Изменение значения коэффициента при рыночном потенциале',fontweight='bold') 
plt.xlabel('Год')
plt.ylabel('Значение коэффициента')
x_0=[0,0,0,0,0,0,0,0]
plt.plot( ym, x_0, color='red')
plt.plot( ym, x_1m, marker='.', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=2)
plt.plot( ym, x_2m, marker='', color='olive', linewidth=4)
plt.plot( ym, x_3m, marker='.', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=2)

# %% [markdown]
# # HIGH (>0,25)

# %%
x_1h=np.array([-0.06509723,0.04066648,0.06526422,-0.07018100,-0.12962580,-0.14733293,0.124114681,0.042009200])
x_2h=np.array([0.10766,0.19302,0.168536,-0.011857,-0.074767,-0.100699,0.158106,0.066227])
x_3h=np.array([0.28041543,0.34536358,0.27180713,0.04646776,-0.019907669,-0.0540650436,0.192097719,0.090444393])
yh=np.array([1926,1939,1959,1970,1979,1989,2002,2010])

tick_val_x = [1926,1939,1959,1970,1979,1989,2002,2010]
tick_lab_x = [1926,1939,1959,1970,1979,1989,2002,2010]
plt.xticks(tick_val_x,tick_lab_x)
# multiple line plot
plt.title('Изменение значения коэффициента при рыночном потенциале (для крупных городов)',fontweight='bold') 
plt.xlabel('Год')
plt.ylabel('Значение коэффициента')
x_0=[0,0,0,0,0,0,0,0]
plt.plot( yh, x_0, color='red')
plt.plot( yh, x_1h, marker='.', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=2, label='Границы доверительного интервала')
plt.plot( yh, x_2h, marker='', color='darkgreen', linewidth=4, label='значение коэффициента')
plt.plot( yh, x_3h, marker='.', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=2)
plt.legend()

# %% [markdown]
# # Whole sample

# %%
x_1=np.array([-8.77261480,-7.07136897,-1.448671875,-2.85558604,-3.13047643,-1.57657586,4.239776416,0.444647941])
x_2=np.array([-5.75467,-3.91999,0.60730,-0.89132,-1.808515,-0.531307,5.031414,1.044523])
x_3=np.array([-2.7367325341,-0.7686152,2.66326764,1.07294833,-0.48655452,0.51396182,5.82305195,1.64439873])
y=np.array([1926,1939,1959,1970,1979,1989,2002,2010])

tick_val_x = [1926,1939,1959,1970,1979,1989,2002,2010]
tick_lab_x = [1926,1939,1959,1970,1979,1989,2002,2010]
plt.xticks(tick_val_x,tick_lab_x)
# multiple line plot
plt.title('Изменение значения коэффициента при рыночном потенциале (для всех городов)',fontweight='bold') 
plt.xlabel('Год')
plt.ylabel('Значение коэффициента')
x_0=[0,0,0,0,0,0,0,0]
plt.plot( y, x_0, color='red')
plt.plot( y, x_1, marker='.', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=2, label='Границы доверительного интервала')
plt.plot( y, x_2, marker='', color='darkgreen', linewidth=4, label='значение коэффициента')
plt.plot( y, x_3, marker='.', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=2)
plt.legend()
