# %%
#подгружаем необходимые библиотеки
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('mutate.csv')
df1=df.drop(['Unnamed: 0'], axis=1)
df1
# Out:
#       ID89             name89                    region            okrug  \
# 0        6       Petrozavodsk          Karel'skaia ASSR  Severno-Zapadny
# 1        8        Kostomuksha          Karel'skaia ASSR  Severno-Zapadny
# 2       10          Sortavala          Karel'skaia ASSR  Severno-Zapadny
# 3       15          Belomorsk          Karel'skaia ASSR  Severno-Zapadny
# 4       21           Kalevala          Karel'skaia ASSR  Severno-Zapadny
# 5       24               Kem'          Karel'skaia ASSR  Severno-Zapadny
# 6       28          Kondopoga          Karel'skaia ASSR  Severno-Zapadny
# 7       31     Lakhdenpokh'ia          Karel'skaia ASSR  Severno-Zapadny
# 8       34             Loukhi          Karel'skaia ASSR  Severno-Zapadny
# 9       37        Piaozerskii          Karel'skaia ASSR  Severno-Zapadny
# 10      39              Chupa          Karel'skaia ASSR  Severno-Zapadny
# 11      41     Medvezh'egorsk          Karel'skaia ASSR  Severno-Zapadny
# ...

# %% [markdown]
# # 1897

# %%
#df_1897_highest=df1[df1['pop1897'] >12853.5]
df_1897_highest=df1[(df1['pop1897'] <1)|(df1['pop1897'] >12853.5)]
df_1897_highest=df_1897_highest.drop(['pop1939','pop1959','pop1970','pop1979','pop1989','pop2002','pop2010','spop1939','spop1959','spop1970','spop1979','spop1989','spop2002','spop2010','mp1939','mp1959','mp1970','mp1979','mp1989','mp2002','mp2010','smp1939','smp1959','smp1970','smp1979','smp1989','smp2002','smp2010'], axis=1)
df_1897_highest['pop1897']=df_1897_highest['pop1897'].replace(0,'NA')
df_1897_highest['pop1926']=df_1897_highest['pop1926'].replace(0,'NA')
df_1897_highest['spop1897']=df_1897_highest['spop1897'].replace(0,'NA')
df_1897_highest['spop1926']=df_1897_highest['spop1926'].replace(0,'NA')
df_1897_highest.to_csv('df_1897_highest.csv')

# %%
df_1897_highest.to_csv('df_1897_highest')
# Out:
#       ID89             name89                    region            okrug  \
# 1        8        Kostomuksha          Karel'skaia ASSR  Severno-Zapadny
# 3       15          Belomorsk          Karel'skaia ASSR  Severno-Zapadny
# 4       21           Kalevala          Karel'skaia ASSR  Severno-Zapadny
# 6       28          Kondopoga          Karel'skaia ASSR  Severno-Zapadny
# 7       31     Lakhdenpokh'ia          Karel'skaia ASSR  Severno-Zapadny
# 8       34             Loukhi          Karel'skaia ASSR  Severno-Zapadny
# 9       37        Piaozerskii          Karel'skaia ASSR  Severno-Zapadny
# 10      39              Chupa          Karel'skaia ASSR  Severno-Zapadny
# 11      41     Medvezh'egorsk          Karel'skaia ASSR  Severno-Zapadny
# 12      42           Pindushi          Karel'skaia ASSR  Severno-Zapadny
# 14      45         Muezerskii          Karel'skaia ASSR  Severno-Zapadny
# 16      50          Il'inskii          Karel'skaia ASSR  Severno-Zapadny
# ...

# %%
df_1897_middle=df1[((df1['pop1897'] <12853.5)&(df1['pop1897'] >3611.5))|(df1['pop1897'] ==0)]
df_1897_middle=df_1897_middle.drop(['pop1939','pop1959','pop1970','pop1979','pop1989','pop2002','pop2010','spop1939','spop1959','spop1970','spop1979','spop1989','spop2002','spop2010','mp1939','mp1959','mp1970','mp1979','mp1989','mp2002','mp2010','smp1939','smp1959','smp1970','smp1979','smp1989','smp2002','smp2010'], axis=1)
df_1897_middle['pop1897']=df_1897_middle['pop1897'].replace(0,'NA')
df_1897_middle['spop1897']=df_1897_middle['spop1897'].replace(0,'NA')
df_1897_middle['pop1926']=df_1897_middle['pop1926'].replace(0,'NA')
df_1897_middle['spop1926']=df_1897_middle['spop1926'].replace(0,'NA')
df_1897_middle.to_csv('df_1897_middle.csv')

# %%
df_1897_middle.to_csv('df_1897_middle')

# %% [markdown]
# # 1926

# %%
df_1926_highest=df1[(df1['pop1926'] <1)|(df1['pop1926'] >15183)]
df_1926_highest=df_1926_highest.drop(['pop1897','spop1897','mp1897','smp1897','pop1959','pop1970','pop1979','pop1989','pop2002','pop2010','spop1959','spop1970','spop1979','spop1989','spop2002','spop2010','mp1959','mp1970','mp1979','mp1989','mp2002','mp2010','smp1959','smp1970','smp1979','smp1989','smp2002','smp2010'], axis=1)
df_1926_highest['pop1926']=df_1926_highest['pop1926'].replace(0,'NA')
df_1926_highest['spop1926']=df_1926_highest['spop1926'].replace(0,'NA')
df_1926_highest['pop1939']=df_1926_highest['pop1939'].replace(0,'NA')
df_1926_highest['spop1939']=df_1926_highest['spop1939'].replace(0,'NA')
df_1926_highest.to_csv('df_1926_highest.csv')

# %%
df_1926_highest.to_csv('df_1926_highest.csv')

# %%
df_1926_high=df1[(df1['pop1926'] <1)|(df1['pop1926'] >3671.5)]
df_1926_high=df_1926_high.drop(['pop1897','spop1897','mp1897','smp1897','pop1959','pop1970','pop1979','pop1989','pop2002','pop2010','spop1959','spop1970','spop1979','spop1989','spop2002','spop2010','mp1959','mp1970','mp1979','mp1989','mp2002','mp2010','smp1959','smp1970','smp1979','smp1989','smp2002','smp2010'], axis=1)
df_1926_high['pop1926']=df_1926_high['pop1926'].replace(0,'NA')
df_1926_high['spop1926']=df_1926_high['spop1926'].replace(0,'NA')
df_1926_high['pop1939']=df_1926_high['pop1939'].replace(0,'NA')
df_1926_high['spop1939']=df_1926_high['spop1939'].replace(0,'NA')
df_1926_high.to_csv('df_1926_high.csv')
#df_1926_high

# %%
df_1926_middle=df1[((df1['pop1926'] <15183)&(df1['pop1926'] >3671.5))|(df1['pop1926'] ==0)]
df_1926_middle=df_1926_middle.drop(['pop1959','pop1970','pop1979','pop1989','pop2002','pop2010','spop1959','spop1970','spop1979','spop1989','spop2002','spop2010','mp1959','mp1970','mp1979','mp1989','mp2002','mp2010','smp1959','smp1970','smp1979','smp1989','smp2002','smp2010'], axis=1)
df_1926_middle['pop1939']=df_1926_middle['pop1939'].replace(0,'NA')
df_1926_middle['spop1939']=df_1926_middle['spop1939'].replace(0,'NA')
df_1926_middle['pop1926']=df_1926_middle['pop1926'].replace(0,'NA')
df_1926_middle['spop1926']=df_1926_middle['spop1926'].replace(0,'NA')
df_1926_middle.to_csv('df_1926_middle.csv')
df_1926_middle
# Out:
#       ID89             name89                    region            okrug  \
# 1        8        Kostomuksha          Karel'skaia ASSR  Severno-Zapadny
# 2       10          Sortavala          Karel'skaia ASSR  Severno-Zapadny
# 3       15          Belomorsk          Karel'skaia ASSR  Severno-Zapadny
# 4       21           Kalevala          Karel'skaia ASSR  Severno-Zapadny
# 5       24               Kem'          Karel'skaia ASSR  Severno-Zapadny
# 7       31     Lakhdenpokh'ia          Karel'skaia ASSR  Severno-Zapadny
# 8       34             Loukhi          Karel'skaia ASSR  Severno-Zapadny
# 9       37        Piaozerskii          Karel'skaia ASSR  Severno-Zapadny
# 10      39              Chupa          Karel'skaia ASSR  Severno-Zapadny
# 12      42           Pindushi          Karel'skaia ASSR  Severno-Zapadny
# 14      45         Muezerskii          Karel'skaia ASSR  Severno-Zapadny
# 16      50          Il'inskii          Karel'skaia ASSR  Severno-Zapadny
# ...

# %%
df_1926_low=df1[df1['pop1926'] <3671.5]
df_1926_low=df_1926_low.drop(['pop1897','spop1897','mp1897','smp1897','pop1959','pop1970','pop1979','pop1989','pop2002','pop2010','spop1959','spop1970','spop1979','spop1989','spop2002','spop2010','mp1959','mp1970','mp1979','mp1989','mp2002','mp2010','smp1959','smp1970','smp1979','smp1989','smp2002','smp2010'], axis=1)
df_1926_low['pop1926']=df_1926_low['pop1926'].replace(0,'NA')
df_1926_low['spop1926']=df_1926_low['spop1926'].replace(0,'NA')
df_1926_low['pop1939']=df_1926_low['pop1939'].replace(0,'NA')
df_1926_low['spop1939']=df_1926_low['spop1939'].replace(0,'NA')
df_1926_low.to_csv('df_1926_low.csv')
df_1926_low
# Out:
#       ID89             name89                    region            okrug  \
# 1        8        Kostomuksha          Karel'skaia ASSR  Severno-Zapadny
# 4       21           Kalevala          Karel'skaia ASSR  Severno-Zapadny
# 6       28          Kondopoga          Karel'skaia ASSR  Severno-Zapadny
# 7       31     Lakhdenpokh'ia          Karel'skaia ASSR  Severno-Zapadny
# 8       34             Loukhi          Karel'skaia ASSR  Severno-Zapadny
# 9       37        Piaozerskii          Karel'skaia ASSR  Severno-Zapadny
# 10      39              Chupa          Karel'skaia ASSR  Severno-Zapadny
# 11      41     Medvezh'egorsk          Karel'skaia ASSR  Severno-Zapadny
# 12      42           Pindushi          Karel'skaia ASSR  Severno-Zapadny
# 13      43           Povenets          Karel'skaia ASSR  Severno-Zapadny
# 14      45         Muezerskii          Karel'skaia ASSR  Severno-Zapadny
# 15      49            Olonets          Karel'skaia ASSR  Severno-Zapadny
# ...

# %% [markdown]
# # 1939

# %%
df_1939_highest=df1[(df1['pop1939'] <1)|(df1['pop1939'] >30070)]
df_1939_highest=df_1939_highest.drop(['pop1897','spop1897','mp1897','smp1897','pop1970','pop1979','pop1989','pop2002','pop2010','spop1970','spop1979','spop1989','spop2002','spop2010','mp1970','mp1979','mp1989','mp2002','mp2010','smp1970','smp1979','smp1989','smp2002','smp2010'], axis=1)
df_1939_highest['pop1959']=df_1939_highest['pop1959'].replace(0,'NA')
df_1939_highest['spop1959']=df_1939_highest['spop1959'].replace(0,'NA')
df_1939_highest['pop1939']=df_1939_highest['pop1939'].replace(0,'NA')
df_1939_highest['spop1939']=df_1939_highest['spop1939'].replace(0,'NA')
df_1939_highest.to_csv('df_1939_highest.csv')
df_1939_highest
# Out:
#       ID89             name89                    region            okrug  \
# 0        6       Petrozavodsk          Karel'skaia ASSR  Severno-Zapadny
# 1        8        Kostomuksha          Karel'skaia ASSR  Severno-Zapadny
# 4       21           Kalevala          Karel'skaia ASSR  Severno-Zapadny
# 7       31     Lakhdenpokh'ia          Karel'skaia ASSR  Severno-Zapadny
# 8       34             Loukhi          Karel'skaia ASSR  Severno-Zapadny
# 9       37        Piaozerskii          Karel'skaia ASSR  Severno-Zapadny
# 10      39              Chupa          Karel'skaia ASSR  Severno-Zapadny
# 12      42           Pindushi          Karel'skaia ASSR  Severno-Zapadny
# 13      43           Povenets          Karel'skaia ASSR  Severno-Zapadny
# 14      45         Muezerskii          Karel'skaia ASSR  Severno-Zapadny
# 16      50          Il'inskii          Karel'skaia ASSR  Severno-Zapadny
# 17      52        Pitkiaranta          Karel'skaia ASSR  Severno-Zapadny
# ...

# %%
df_1939_high=df1[(df1['pop1939'] <1)|(df1['pop1939'] >8500)]
df_1939_high=df_1939_high.drop(['pop1897','spop1897','mp1897','smp1897','pop1970','pop1979','pop1989','pop2002','pop2010','spop1970','spop1979','spop1989','spop2002','spop2010','mp1970','mp1979','mp1989','mp2002','mp2010','smp1970','smp1979','smp1989','smp2002','smp2010'], axis=1)
df_1939_high['pop1959']=df_1939_high['pop1959'].replace(0,'NA')
df_1939_high['spop1959']=df_1939_high['spop1959'].replace(0,'NA')
df_1939_high['pop1939']=df_1939_high['pop1939'].replace(0,'NA')
df_1939_high['spop1939']=df_1939_high['spop1939'].replace(0,'NA')
df_1939_high.to_csv('df_1939_high.csv')
df_1939_high
# Out:
#       ID89             name89                    region            okrug  \
# 0        6       Petrozavodsk          Karel'skaia ASSR  Severno-Zapadny
# 1        8        Kostomuksha          Karel'skaia ASSR  Severno-Zapadny
# 3       15          Belomorsk          Karel'skaia ASSR  Severno-Zapadny
# 4       21           Kalevala          Karel'skaia ASSR  Severno-Zapadny
# 5       24               Kem'          Karel'skaia ASSR  Severno-Zapadny
# 6       28          Kondopoga          Karel'skaia ASSR  Severno-Zapadny
# 7       31     Lakhdenpokh'ia          Karel'skaia ASSR  Severno-Zapadny
# 8       34             Loukhi          Karel'skaia ASSR  Severno-Zapadny
# 9       37        Piaozerskii          Karel'skaia ASSR  Severno-Zapadny
# 10      39              Chupa          Karel'skaia ASSR  Severno-Zapadny
# 11      41     Medvezh'egorsk          Karel'skaia ASSR  Severno-Zapadny
# 12      42           Pindushi          Karel'skaia ASSR  Severno-Zapadny
# ...

# %%
df_1939_low=df1[df1['pop1939'] <8500]
df_1939_low=df_1939_low.drop(['pop1897','spop1897','mp1897','smp1897','pop1970','pop1979','pop1989','pop2002','pop2010','spop1970','spop1979','spop1989','spop2002','spop2010','mp1970','mp1979','mp1989','mp2002','mp2010','smp1970','smp1979','smp1989','smp2002','smp2010'], axis=1)
df_1939_low['pop1959']=df_1939_low['pop1959'].replace(0,'NA')
df_1939_low['spop1959']=df_1939_low['spop1959'].replace(0,'NA')
df_1939_low['pop1939']=df_1939_low['pop1939'].replace(0,'NA')
df_1939_low['spop1939']=df_1939_low['spop1939'].replace(0,'NA')
df_1939_low.to_csv('df_1939_low.csv')
df_1939_low
# Out:
#       ID89             name89                    region            okrug  \
# 1        8        Kostomuksha          Karel'skaia ASSR  Severno-Zapadny
# 2       10          Sortavala          Karel'skaia ASSR  Severno-Zapadny
# 4       21           Kalevala          Karel'skaia ASSR  Severno-Zapadny
# 7       31     Lakhdenpokh'ia          Karel'skaia ASSR  Severno-Zapadny
# 8       34             Loukhi          Karel'skaia ASSR  Severno-Zapadny
# 9       37        Piaozerskii          Karel'skaia ASSR  Severno-Zapadny
# 10      39              Chupa          Karel'skaia ASSR  Severno-Zapadny
# 12      42           Pindushi          Karel'skaia ASSR  Severno-Zapadny
# 13      43           Povenets          Karel'skaia ASSR  Severno-Zapadny
# 14      45         Muezerskii          Karel'skaia ASSR  Severno-Zapadny
# 15      49            Olonets          Karel'skaia ASSR  Severno-Zapadny
# 16      50          Il'inskii          Karel'skaia ASSR  Severno-Zapadny
# ...

# %%
df_1939_middle=df1[((df1['pop1939'] <30070)&(df1['pop1939'] >8500))|(df1['pop1939'] ==0)]
df_1939_middle=df_1939_middle.drop(['pop1897','spop1897','mp1897','smp1897','pop1970','pop1979','pop1989','pop2002','pop2010','spop1970','spop1979','spop1989','spop2002','spop2010','mp1970','mp1979','mp1989','mp2002','mp2010','smp1970','smp1979','smp1989','smp2002','smp2010'], axis=1)
df_1939_middle['pop1959']=df_1939_middle['pop1959'].replace(0,'NA')
df_1939_middle['spop1959']=df_1939_middle['spop1959'].replace(0,'NA')
df_1939_middle['pop1939']=df_1939_middle['pop1939'].replace(0,'NA')
df_1939_middle['spop1939']=df_1939_middle['spop1939'].replace(0,'NA')
df_1939_middle.to_csv('df_1939_middle.csv')
df_1939_middle
# Out:
#       ID89             name89                    region            okrug  \
# 1        8        Kostomuksha          Karel'skaia ASSR  Severno-Zapadny
# 3       15          Belomorsk          Karel'skaia ASSR  Severno-Zapadny
# 4       21           Kalevala          Karel'skaia ASSR  Severno-Zapadny
# 5       24               Kem'          Karel'skaia ASSR  Severno-Zapadny
# 6       28          Kondopoga          Karel'skaia ASSR  Severno-Zapadny
# 7       31     Lakhdenpokh'ia          Karel'skaia ASSR  Severno-Zapadny
# 8       34             Loukhi          Karel'skaia ASSR  Severno-Zapadny
# 9       37        Piaozerskii          Karel'skaia ASSR  Severno-Zapadny
# 10      39              Chupa          Karel'skaia ASSR  Severno-Zapadny
# 11      41     Medvezh'egorsk          Karel'skaia ASSR  Severno-Zapadny
# 12      42           Pindushi          Karel'skaia ASSR  Severno-Zapadny
# 13      43           Povenets          Karel'skaia ASSR  Severno-Zapadny
# ...

# %% [markdown]
# # 1959

# %%
df_1959_highest=df1[(df1['pop1959'] <1)|(df1['pop1959'] >39557.5)]
df_1959_highest=df_1959_highest.drop(['pop1897','spop1897','mp1897','smp1897','pop1979','pop1989','pop2002','pop2010','spop1979','spop1989','spop2002','spop2010','mp1979','mp1989','mp2002','mp2010','smp1979','smp1989','smp2002','smp2010'], axis=1)
df_1959_highest['pop1959']=df_1959_highest['pop1959'].replace(0,'NA')
df_1959_highest['spop1959']=df_1959_highest['spop1959'].replace(0,'NA')
df_1959_highest['pop1970']=df_1959_highest['pop1970'].replace(0,'NA')
df_1959_highest['spop1970']=df_1959_highest['spop1970'].replace(0,'NA')
df_1959_highest.to_csv('df_1959_highest.csv')
df_1959_highest
# Out:
#       ID89             name89                    region            okrug  \
# 0        6       Petrozavodsk          Karel'skaia ASSR  Severno-Zapadny
# 1        8        Kostomuksha          Karel'skaia ASSR  Severno-Zapadny
# 4       21           Kalevala          Karel'skaia ASSR  Severno-Zapadny
# 8       34             Loukhi          Karel'skaia ASSR  Severno-Zapadny
# 9       37        Piaozerskii          Karel'skaia ASSR  Severno-Zapadny
# 10      39              Chupa          Karel'skaia ASSR  Severno-Zapadny
# 12      42           Pindushi          Karel'skaia ASSR  Severno-Zapadny
# 13      43           Povenets          Karel'skaia ASSR  Severno-Zapadny
# 14      45         Muezerskii          Karel'skaia ASSR  Severno-Zapadny
# 16      50          Il'inskii          Karel'skaia ASSR  Severno-Zapadny
# 17      52        Pitkiaranta          Karel'skaia ASSR  Severno-Zapadny
# 18      54          Liaskelia          Karel'skaia ASSR  Severno-Zapadny
# ...

# %%
df_1959_high=df1[(df1['pop1959'] <1)|(df1['pop1959'] >10900)]
df_1959_high=df_1959_high.drop(['pop1897','spop1897','mp1897','smp1897','pop1979','pop1989','pop2002','pop2010','spop1979','spop1989','spop2002','spop2010','mp1979','mp1989','mp2002','mp2010','smp1979','smp1989','smp2002','smp2010'], axis=1)
df_1959_high['pop1959']=df_1959_high['pop1959'].replace(0,'NA')
df_1959_high['spop1959']=df_1959_high['spop1959'].replace(0,'NA')
df_1959_high['pop1970']=df_1959_high['pop1970'].replace(0,'NA')
df_1959_high['spop1970']=df_1959_high['spop1970'].replace(0,'NA')
df_1959_high.to_csv('df_1959_high.csv')
df_1959_high
# Out:
#       ID89             name89                    region            okrug  \
# 0        6       Petrozavodsk          Karel'skaia ASSR  Severno-Zapadny
# 1        8        Kostomuksha          Karel'skaia ASSR  Severno-Zapadny
# 2       10          Sortavala          Karel'skaia ASSR  Severno-Zapadny
# 3       15          Belomorsk          Karel'skaia ASSR  Severno-Zapadny
# 4       21           Kalevala          Karel'skaia ASSR  Severno-Zapadny
# 5       24               Kem'          Karel'skaia ASSR  Severno-Zapadny
# 6       28          Kondopoga          Karel'skaia ASSR  Severno-Zapadny
# 8       34             Loukhi          Karel'skaia ASSR  Severno-Zapadny
# 9       37        Piaozerskii          Karel'skaia ASSR  Severno-Zapadny
# 10      39              Chupa          Karel'skaia ASSR  Severno-Zapadny
# 11      41     Medvezh'egorsk          Karel'skaia ASSR  Severno-Zapadny
# 12      42           Pindushi          Karel'skaia ASSR  Severno-Zapadny
# ...

# %%
df_1959_low=df1[df1['pop1959'] <10900]
df_1959_low=df_1959_low.drop(['pop1897','spop1897','mp1897','smp1897','pop1979','pop1989','pop2002','pop2010','spop1979','spop1989','spop2002','spop2010','mp1979','mp1989','mp2002','mp2010','smp1979','smp1989','smp2002','smp2010'], axis=1)
df_1959_low['pop1959']=df_1959_low['pop1959'].replace(0,'NA')
df_1959_low['spop1959']=df_1959_low['spop1959'].replace(0,'NA')
df_1959_low['pop1970']=df_1959_low['pop1970'].replace(0,'NA')
df_1959_low['spop1970']=df_1959_low['spop1970'].replace(0,'NA')
df_1959_low.to_csv('df_1959_low.csv')
df_1959_low
# Out:
#       ID89             name89                    region            okrug  \
# 1        8        Kostomuksha          Karel'skaia ASSR  Severno-Zapadny
# 4       21           Kalevala          Karel'skaia ASSR  Severno-Zapadny
# 7       31     Lakhdenpokh'ia          Karel'skaia ASSR  Severno-Zapadny
# 8       34             Loukhi          Karel'skaia ASSR  Severno-Zapadny
# 9       37        Piaozerskii          Karel'skaia ASSR  Severno-Zapadny
# 10      39              Chupa          Karel'skaia ASSR  Severno-Zapadny
# 12      42           Pindushi          Karel'skaia ASSR  Severno-Zapadny
# 13      43           Povenets          Karel'skaia ASSR  Severno-Zapadny
# 14      45         Muezerskii          Karel'skaia ASSR  Severno-Zapadny
# 15      49            Olonets          Karel'skaia ASSR  Severno-Zapadny
# 16      50          Il'inskii          Karel'skaia ASSR  Severno-Zapadny
# 17      52        Pitkiaranta          Karel'skaia ASSR  Severno-Zapadny
# ...

# %%
df_1959_middle=df1[((df1['pop1939'] <39557.5)&(df1['pop1939'] >10900))|(df1['pop1939'] ==0)]
df_1959_middle=df_1959_middle.drop(['pop1897','spop1897','mp1897','smp1897','pop1979','pop1989','pop2002','pop2010','spop1979','spop1989','spop2002','spop2010','mp1979','mp1989','mp2002','mp2010','smp1979','smp1989','smp2002','smp2010'], axis=1)
df_1959_middle['pop1959']=df_1959_middle['pop1959'].replace(0,'NA')
df_1959_middle['spop1959']=df_1959_middle['spop1959'].replace(0,'NA')
df_1959_middle['pop1970']=df_1959_middle['pop1970'].replace(0,'NA')
df_1959_middle['spop1970']=df_1959_middle['spop1970'].replace(0,'NA')
df_1959_middle.to_csv('df_1959_middle.csv')
df_1959_middle
# Out:
#       ID89             name89                    region            okrug  \
# 1        8        Kostomuksha          Karel'skaia ASSR  Severno-Zapadny
# 4       21           Kalevala          Karel'skaia ASSR  Severno-Zapadny
# 5       24               Kem'          Karel'skaia ASSR  Severno-Zapadny
# 6       28          Kondopoga          Karel'skaia ASSR  Severno-Zapadny
# 7       31     Lakhdenpokh'ia          Karel'skaia ASSR  Severno-Zapadny
# 8       34             Loukhi          Karel'skaia ASSR  Severno-Zapadny
# 9       37        Piaozerskii          Karel'skaia ASSR  Severno-Zapadny
# 10      39              Chupa          Karel'skaia ASSR  Severno-Zapadny
# 11      41     Medvezh'egorsk          Karel'skaia ASSR  Severno-Zapadny
# 12      42           Pindushi          Karel'skaia ASSR  Severno-Zapadny
# 13      43           Povenets          Karel'skaia ASSR  Severno-Zapadny
# 14      45         Muezerskii          Karel'skaia ASSR  Severno-Zapadny
# ...

# %% [markdown]
# # 1970

# %%
df_1970_highest=df1[(df1['pop1970'] <1)|(df1['pop1970'] >48300)]
df_1970_highest=df_1970_highest.drop(['pop1897','spop1897','mp1897','smp1897','pop1989','pop2002','pop2010','spop1989','spop2002','spop2010','mp1989','mp2002','mp2010','smp1989','smp2002','smp2010'], axis=1)
df_1970_highest['pop1979']=df_1970_highest['pop1979'].replace(0,'NA')
df_1970_highest['spop1979']=df_1970_highest['spop1979'].replace(0,'NA')
df_1970_highest['pop1970']=df_1970_highest['pop1970'].replace(0,'NA')
df_1970_highest['spop1970']=df_1970_highest['spop1970'].replace(0,'NA')
df_1970_highest.to_csv('df_1970_highest.csv')
df_1970_highest
# Out:
#       ID89             name89                    region            okrug  \
# 0        6       Petrozavodsk          Karel'skaia ASSR  Severno-Zapadny
# 1        8        Kostomuksha          Karel'skaia ASSR  Severno-Zapadny
# 4       21           Kalevala          Karel'skaia ASSR  Severno-Zapadny
# 8       34             Loukhi          Karel'skaia ASSR  Severno-Zapadny
# 9       37        Piaozerskii          Karel'skaia ASSR  Severno-Zapadny
# 10      39              Chupa          Karel'skaia ASSR  Severno-Zapadny
# 12      42           Pindushi          Karel'skaia ASSR  Severno-Zapadny
# 13      43           Povenets          Karel'skaia ASSR  Severno-Zapadny
# 14      45         Muezerskii          Karel'skaia ASSR  Severno-Zapadny
# 16      50          Il'inskii          Karel'skaia ASSR  Severno-Zapadny
# 18      54          Liaskelia          Karel'skaia ASSR  Severno-Zapadny
# 19      63              Shuia          Karel'skaia ASSR  Severno-Zapadny
# ...

# %%
df_1970_high=df1[(df1['pop1970'] <1)|(df1['pop1970'] >13075)]
df_1970_high=df_1970_high.drop(['pop1897','spop1897','mp1897','smp1897','pop1989','pop2002','pop2010','spop1989','spop2002','spop2010','mp1989','mp2002','mp2010','smp1989','smp2002','smp2010'], axis=1)
df_1970_high['pop1979']=df_1970_high['pop1979'].replace(0,'NA')
df_1970_high['spop1979']=df_1970_high['spop1979'].replace(0,'NA')
df_1970_high['pop1970']=df_1970_high['pop1970'].replace(0,'NA')
df_1970_high['spop1970']=df_1970_high['spop1970'].replace(0,'NA')
df_1970_high.to_csv('df_1970_high.csv')
df_1970_high
# Out:
#       ID89             name89                    region            okrug  \
# 0        6       Petrozavodsk          Karel'skaia ASSR  Severno-Zapadny
# 1        8        Kostomuksha          Karel'skaia ASSR  Severno-Zapadny
# 2       10          Sortavala          Karel'skaia ASSR  Severno-Zapadny
# 3       15          Belomorsk          Karel'skaia ASSR  Severno-Zapadny
# 4       21           Kalevala          Karel'skaia ASSR  Severno-Zapadny
# 5       24               Kem'          Karel'skaia ASSR  Severno-Zapadny
# 6       28          Kondopoga          Karel'skaia ASSR  Severno-Zapadny
# 8       34             Loukhi          Karel'skaia ASSR  Severno-Zapadny
# 9       37        Piaozerskii          Karel'skaia ASSR  Severno-Zapadny
# 10      39              Chupa          Karel'skaia ASSR  Severno-Zapadny
# 11      41     Medvezh'egorsk          Karel'skaia ASSR  Severno-Zapadny
# 12      42           Pindushi          Karel'skaia ASSR  Severno-Zapadny
# ...

# %%
df_1970_low=df1[df1['pop1970'] <13076]
df_1970_low=df_1970_low.drop(['pop1897','spop1897','mp1897','smp1897','pop1989','pop2002','pop2010','spop1989','spop2002','spop2010','mp1989','mp2002','mp2010','smp1989','smp2002','smp2010'], axis=1)
df_1970_low['pop1979']=df_1970_low['pop1979'].replace(0,'NA')
df_1970_low['spop1979']=df_1970_low['spop1979'].replace(0,'NA')
df_1970_low['pop1970']=df_1970_low['pop1970'].replace(0,'NA')
df_1970_low['spop1970']=df_1970_low['spop1970'].replace(0,'NA')
df_1970_low.to_csv('df_1970_low.csv')
df_1970_low
# Out:
#       ID89             name89                    region            okrug  \
# 1        8        Kostomuksha          Karel'skaia ASSR  Severno-Zapadny
# 4       21           Kalevala          Karel'skaia ASSR  Severno-Zapadny
# 7       31     Lakhdenpokh'ia          Karel'skaia ASSR  Severno-Zapadny
# 8       34             Loukhi          Karel'skaia ASSR  Severno-Zapadny
# 9       37        Piaozerskii          Karel'skaia ASSR  Severno-Zapadny
# 10      39              Chupa          Karel'skaia ASSR  Severno-Zapadny
# 12      42           Pindushi          Karel'skaia ASSR  Severno-Zapadny
# 13      43           Povenets          Karel'skaia ASSR  Severno-Zapadny
# 14      45         Muezerskii          Karel'skaia ASSR  Severno-Zapadny
# 15      49            Olonets          Karel'skaia ASSR  Severno-Zapadny
# 16      50          Il'inskii          Karel'skaia ASSR  Severno-Zapadny
# 17      52        Pitkiaranta          Karel'skaia ASSR  Severno-Zapadny
# ...

# %%
df_1970_middle=df1[((df1['pop1970'] <48300)&(df1['pop1970'] >13075))|(df1['pop1970'] ==0)]
df_1970_middle=df_1970_middle.drop(['pop1897','spop1897','mp1897','smp1897','pop1989','pop2002','pop2010','spop1989','spop2002','spop2010','mp1989','mp2002','mp2010','smp1989','smp2002','smp2010'], axis=1)
df_1970_middle['pop1979']=df_1970_middle['pop1979'].replace(0,'NA')
df_1970_middle['spop1979']=df_1970_middle['spop1979'].replace(0,'NA')
df_1970_middle['pop1970']=df_1970_middle['pop1970'].replace(0,'NA')
df_1970_middle['spop1970']=df_1970_middle['spop1970'].replace(0,'NA')
df_1970_middle.to_csv('df_1970_middle.csv')
df_1970_middle
# Out:
#       ID89             name89                    region            okrug  \
# 1        8        Kostomuksha          Karel'skaia ASSR  Severno-Zapadny
# 2       10          Sortavala          Karel'skaia ASSR  Severno-Zapadny
# 3       15          Belomorsk          Karel'skaia ASSR  Severno-Zapadny
# 4       21           Kalevala          Karel'skaia ASSR  Severno-Zapadny
# 5       24               Kem'          Karel'skaia ASSR  Severno-Zapadny
# 6       28          Kondopoga          Karel'skaia ASSR  Severno-Zapadny
# 8       34             Loukhi          Karel'skaia ASSR  Severno-Zapadny
# 9       37        Piaozerskii          Karel'skaia ASSR  Severno-Zapadny
# 10      39              Chupa          Karel'skaia ASSR  Severno-Zapadny
# 11      41     Medvezh'egorsk          Karel'skaia ASSR  Severno-Zapadny
# 12      42           Pindushi          Karel'skaia ASSR  Severno-Zapadny
# 13      43           Povenets          Karel'skaia ASSR  Severno-Zapadny
# ...

# %% [markdown]
# # 1979

# %%
df_1979_highest=df1[(df1['pop1979'] <1)|(df1['pop1979'] >55799)]
df_1979_highest=df_1979_highest.drop(['pop1897','spop1897','mp1897','smp1897','pop2002','pop2010','spop2002','spop2010','mp2002','mp2010','smp2002','smp2010'], axis=1)
df_1979_highest['pop1989']=df_1979_highest['pop1989'].replace(0,'NA')
df_1979_highest['spop1989']=df_1979_highest['spop1989'].replace(0,'NA')
df_1979_highest['pop1979']=df_1979_highest['pop1979'].replace(0,'NA')
df_1979_highest['spop1979']=df_1979_highest['spop1979'].replace(0,'NA')
df_1979_highest.to_csv('df_1979_highest.csv')
df_1979_highest
# Out:
#       ID89             name89                    region            okrug  \
# 0        6       Petrozavodsk          Karel'skaia ASSR  Severno-Zapadny
# 4       21           Kalevala          Karel'skaia ASSR  Severno-Zapadny
# 8       34             Loukhi          Karel'skaia ASSR  Severno-Zapadny
# 9       37        Piaozerskii          Karel'skaia ASSR  Severno-Zapadny
# 10      39              Chupa          Karel'skaia ASSR  Severno-Zapadny
# 12      42           Pindushi          Karel'skaia ASSR  Severno-Zapadny
# 13      43           Povenets          Karel'skaia ASSR  Severno-Zapadny
# 14      45         Muezerskii          Karel'skaia ASSR  Severno-Zapadny
# 16      50          Il'inskii          Karel'skaia ASSR  Severno-Zapadny
# 18      54          Liaskelia          Karel'skaia ASSR  Severno-Zapadny
# 19      63              Shuia          Karel'skaia ASSR  Severno-Zapadny
# 20      65            Priazha          Karel'skaia ASSR  Severno-Zapadny
# ...

# %%
df_1979_high=df1[(df1['pop1979'] <1)|(df1['pop1979'] >14599)]
df_1979_high=df_1979_high.drop(['pop1897','spop1897','mp1897','smp1897','pop2002','pop2010','spop2002','spop2010','mp2002','mp2010','smp2002','smp2010'], axis=1)
df_1979_high['pop1989']=df_1979_high['pop1989'].replace(0,'NA')
df_1979_high['spop1989']=df_1979_high['spop1989'].replace(0,'NA')
df_1979_high['pop1979']=df_1979_high['pop1979'].replace(0,'NA')
df_1979_high['spop1979']=df_1979_high['spop1979'].replace(0,'NA')
df_1979_high.to_csv('df_1979_high.csv')
df_1979_high
# Out:
#       ID89             name89                    region            okrug  \
# 0        6       Petrozavodsk          Karel'skaia ASSR  Severno-Zapadny
# 2       10          Sortavala          Karel'skaia ASSR  Severno-Zapadny
# 3       15          Belomorsk          Karel'skaia ASSR  Severno-Zapadny
# 4       21           Kalevala          Karel'skaia ASSR  Severno-Zapadny
# 5       24               Kem'          Karel'skaia ASSR  Severno-Zapadny
# 6       28          Kondopoga          Karel'skaia ASSR  Severno-Zapadny
# 8       34             Loukhi          Karel'skaia ASSR  Severno-Zapadny
# 9       37        Piaozerskii          Karel'skaia ASSR  Severno-Zapadny
# 10      39              Chupa          Karel'skaia ASSR  Severno-Zapadny
# 11      41     Medvezh'egorsk          Karel'skaia ASSR  Severno-Zapadny
# 12      42           Pindushi          Karel'skaia ASSR  Severno-Zapadny
# 13      43           Povenets          Karel'skaia ASSR  Severno-Zapadny
# ...
